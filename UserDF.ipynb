# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from networkx.algorithms import bipartite

# %%
# business = pd.read_json('business.json', lines=True)

# %%
# business.head()

# %%
# tip = pd.read_json('tip.json', lines=True)
#user = pd.read_json('user.json', lines=True)

# %%
# tip.head(5)

# %%
# checkin = pd.read_json('checkin.json', lines=True)

# %%
# checkin.head()

# %%
user = pd.read_json('user.json', lines=True)

# %%
user.head()
# Out:
#    average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0           4.03                1                0                 1
# 1           3.63                1                0                 1
# 2           3.71                0                0                 0
# 3           4.85                0                0                 0
# 4           4.08               80                0                80
#
#    compliment_hot  compliment_list  compliment_more  compliment_note  \
# 0               2                0                0                1
# 1               1                0                0                0
# 2               0                0                0                1
# 3               1                0                0                0
# 4              28                1                1               16
#
#    compliment_photos  compliment_plain  ...  cool                elite  fans  \
# ...

# %%
user.drop(['compliment_cool', 'compliment_cute', 'compliment_funny', 'compliment_hot', 'compliment_list', 'compliment_more', 'compliment_note', 'compliment_photos', 'compliment_plain', 'compliment_profile', 'compliment_writer', 'funny', 'yelping_since'], axis=1, inplace=True)

# %%
user.head(35)
# Out:
#     average_stars   cool                                    elite  fans  \
# 0            4.03     25                           2015,2016,2017     5
# 1            3.63     16                                              4
# 2            3.71     10                                              0
# 3            4.85     14                                              5
# 4            4.08    665                      2015,2016,2017,2018    39
# 5            4.20   3048                      2015,2016,2017,2018   186
# 6            4.39  15319  2006,2007,2008,2009,2010,2011,2012,2013   696
# 7            4.33      1                                              0
# 8            4.21   1244       2006,2007,2008,2009,2010,2011,2012    57
# 9            4.53    185                                             15
# 10           3.60     34                                2017,2018     9
# 11           3.48     22                                              3
# ...

# %%
user.elite
# Out:
# 0                                   2015,2016,2017
# 1
# 2
# 3
# 4                              2015,2016,2017,2018
# 5                              2015,2016,2017,2018
# 6          2006,2007,2008,2009,2010,2011,2012,2013
# 7
# 8               2006,2007,2008,2009,2010,2011,2012
# 9
# 10                                       2017,2018
# 11
# 12
# 13
# 14
# 15
# 16                   2011,2012,2013,2014,2015,2016
# 17
# 18                        2014,2015,2016,2017,2018
# 19
# 20                        2013,2014,2016,2017,2018
# 21                             2015,2016,2017,2018
# 22
# 23                                       2008,2009
# 24                   2012,2013,2014,2015,2016,2017
# 25
# 26
# 27                                       2016,2017
# 28
# 29
#                             ...
# 1637108
# 1637109
# 1637110
# 1637111
# 1637112
# 1637113
# 1637114
# 1637115
# 1637116
# 1637117
# 1637118
# 1637119
# 1637120
# 1637121
# 1637122
# 1637123
# 1637124
# 1637125
# 1637126
# ...

# %%
user['elite'].value_counts().head(600)
# Out:
#                                                           1565761
# 2017,2018                                                    9316
# 2018                                                         8986
# 2016,2017,2018                                               5975
# 2015,2016,2017,2018                                          4521
# 2016,2017                                                    2233
# 2014,2015,2016,2017,2018                                     2167
# 2012,2013,2014,2015,2016,2017,2018                           1858
# 2015,2016                                                    1850
# 2015,2016,2017                                               1606
# 2013,2014,2015,2016,2017,2018                                1512
# 2017                                                         1320
# 2012                                                         1087
# 2011,2012,2013,2014,2015,2016,2017,2018                      1010
# ...

# %%
# user_elite_title= user[user['elite'].contain(['2018'])]
# user_elite_title.head(5)
user_elite_title = user[user.elite.str.contains('2018')]

# %%
user_elite_title.shape
# Out:
# (38630, 10)

# %%
user_elite_title.head(2)
# Out:
#    average_stars  cool                elite  fans  \
# 4           4.08   665  2015,2016,2017,2018    39
# 5           4.20  3048  2015,2016,2017,2018   186
#
#                                              friends     name  review_count  \
# 4  mbwrZ-RS76V1HoJ0bF_Geg, g64lOV39xSLRZO0aQQ6DeQ...    Nancy           361
# 5  AJxDPGVTzefy3vSHWJchvQ, TgveR4qIsr0Q7b4MJK29TA...  Marilyn           214
#
#    useful                 user_id  elite_title
# 4    1114  MM4RJAeH6yuaN8oZDSt0RA        False
# 5    3475  0rK89TS8xqy1wI4nYI1wfw        False
